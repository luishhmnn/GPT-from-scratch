# %% [markdown]
# ## Tokenizer
# In this notebook, OpenAI's byte pair encoding (BPE) tokenizer _ticktoken_ is used to tokenize text.

# %%
from importlib.metadata import version
import tiktoken
print("tiktoken version:", version("tiktoken"))
# Out:
# tiktoken version: 0.12.0

# %%
tokenizer = tiktoken.get_encoding("gpt2")

# %%
text = "Hello, how are you? <|endoftext|> I like superkaligrafilistischexpiallegorisch."
tokens = tokenizer.encode(text, allowed_special={"<|endoftext|>"})
print(tokens)
# Out:
# [15496, 11, 703, 389, 345, 30, 220, 50256, 314, 588, 8887, 13]

# %%
tokenizer.decode(tokens)
# Out:
# 'Hello, how are you? <|endoftext|> I like tea.'
